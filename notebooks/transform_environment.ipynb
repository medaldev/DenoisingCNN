# %%
from applications.denoiser_environment import DenoiserEnvironment
import torch

PATH_BASE = "/home/amedvedev/fprojects/python/denoising"
NAME_DATASET = "gcg18"
width, height = 30, 30
env = DenoiserEnvironment(name_model="model_13", name_dataset=NAME_DATASET, path_base=PATH_BASE)
env.device = torch.device("cuda:0")

# %%
import models
# env.init_model(models.autoencoders.ConvAutoencoderLuma)
env.init_model(models.UvychToKre3)
# Out:
# New model created.

# %%
env.load_model(model_type="pt")
# Out:
# New model created.
# Error when loading pretrained model. Use custom. [Errno 2] No such file or directory: '/home/amedvedev/fprojects/python/denoising/assets/pt/model_13.pt'

# %%
from common.fstream import read_tensor, read_matrix
env.load_data(width, height, batch_size=4, read_tensor_x=read_matrix, read_tensor_y=read_matrix)

# %%
scores_before, scores = env.score(show=True)
# Out:
# /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/_tensor.py:836: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")

# %%
env.train(epochs=5,
          step_saving=False, step_plotting=False,
          optimizer=torch.optim.SGD(env.model.parameters(), lr=0.01, weight_decay=1e-5),
          criterion=torch.nn.MSELoss()
)
# Out:
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 1 	Training Loss: 0.603391 	Validating Loss: 0.681398 	Time: 0.77 m
#
# ====================================================================================================
#
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 2 	Training Loss: 0.598242 	Validating Loss: 0.679327 	Time: 0.77 m
#
# ====================================================================================================
#
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 3 	Training Loss: 0.593738 	Validating Loss: 0.678092 	Time: 0.77 m
#
# ====================================================================================================
#
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 4 	Training Loss: 0.589519 	Validating Loss: 0.677595 	Time: 0.77 m
#
# ====================================================================================================
#
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 5 	Training Loss: 0.585395 	Validating Loss: 0.678083 	Time: 0.77 m
#
# ====================================================================================================

# %%
env.show_metrics(n_last=5)

# %%
scores_before, scores = env.score(show=True)

# %%
env.save(pth=True, onnx=True)
# Out:
# Exported graph: graph(%img : Float(1, 1, 30, 30, strides=[900, 900, 30, 1], requires_grad=0, device=cuda:0),
#       %all_layers.0.weight : Float(76, 1, 3, 3, strides=[9, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %all_layers.0.bias : Float(76, strides=[1], requires_grad=1, device=cuda:0),
#       %all_layers.3.weight : Float(38, 76, 2, 2, strides=[304, 4, 2, 1], requires_grad=1, device=cuda:0),
#       %all_layers.3.bias : Float(38, strides=[1], requires_grad=1, device=cuda:0),
#       %all_layers.6.weight : Float(38, 38, 2, 2, strides=[152, 4, 2, 1], requires_grad=1, device=cuda:0),
#       %all_layers.6.bias : Float(38, strides=[1], requires_grad=1, device=cuda:0),
#       %all_layers.9.weight : Float(38, 38, 2, 2, strides=[152, 4, 2, 1], requires_grad=1, device=cuda:0),
#       %all_layers.9.bias : Float(38, strides=[1], requires_grad=1, device=cuda:0),
#       %all_layers.11.weight : Float(38, 76, 2, 2, strides=[304, 4, 2, 1], requires_grad=1, device=cuda:0),
#       %all_layers.11.bias : Float(76, strides=[1], requires_grad=1, device=cuda:0),
#       %all_layers.13.weight : Float(76, 1, 2, 2, strides=[4, 4, 2, 1], requires_grad=1, device=cuda:0),
#       %all_layers.13.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0)):
#   %/all_layers/all_layers.0/Conv_output_0 : Float(1, 76, 30, 30, strides=[68400, 900, 30, 1], requires_grad=0, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/all_layers/all_layers.0/Conv"](%img, %all_layers.0.weight, %all_layers.0.bias), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.conv.Conv2d::all_layers.0 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:456:0
#   %/all_layers/all_layers.1/Relu_output_0 : Float(1, 76, 30, 30, strides=[68400, 900, 30, 1], requires_grad=0, device=cuda:0) = onnx::Relu[onnx_name="/all_layers/all_layers.1/Relu"](%/all_layers/all_layers.0/Conv_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.activation.ReLU::all_layers.1 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:1471:0
#   %/all_layers/all_layers.2/MaxPool_output_0 : Float(1, 76, 29, 29, strides=[63916, 841, 29, 1], requires_grad=0, device=cuda:0) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/all_layers/all_layers.2/MaxPool"](%/all_layers/all_layers.1/Relu_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.pooling.MaxPool2d::all_layers.2 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:791:0
#   %/all_layers/all_layers.3/Conv_output_0 : Float(1, 38, 28, 28, strides=[29792, 784, 28, 1], requires_grad=0, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/all_layers/all_layers.3/Conv"](%/all_layers/all_layers.2/MaxPool_output_0, %all_layers.3.weight, %all_layers.3.bias), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.conv.Conv2d::all_layers.3 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:456:0
#   %/all_layers/all_layers.4/Relu_output_0 : Float(1, 38, 28, 28, strides=[29792, 784, 28, 1], requires_grad=0, device=cuda:0) = onnx::Relu[onnx_name="/all_layers/all_layers.4/Relu"](%/all_layers/all_layers.3/Conv_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.activation.ReLU::all_layers.4 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:1471:0
#   %/all_layers/all_layers.5/MaxPool_output_0 : Float(1, 38, 27, 27, strides=[27702, 729, 27, 1], requires_grad=0, device=cuda:0) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/all_layers/all_layers.5/MaxPool"](%/all_layers/all_layers.4/Relu_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.pooling.MaxPool2d::all_layers.5 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:791:0
#   %/all_layers/all_layers.6/Conv_output_0 : Float(1, 38, 26, 26, strides=[25688, 676, 26, 1], requires_grad=0, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/all_layers/all_layers.6/Conv"](%/all_layers/all_layers.5/MaxPool_output_0, %all_layers.6.weight, %all_layers.6.bias), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.conv.Conv2d::all_layers.6 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:456:0
#   %/all_layers/all_layers.7/Relu_output_0 : Float(1, 38, 26, 26, strides=[25688, 676, 26, 1], requires_grad=0, device=cuda:0) = onnx::Relu[onnx_name="/all_layers/all_layers.7/Relu"](%/all_layers/all_layers.6/Conv_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.activation.ReLU::all_layers.7 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:1471:0
#   %/all_layers/all_layers.8/MaxPool_output_0 : Float(1, 38, 27, 27, strides=[27702, 729, 27, 1], requires_grad=0, device=cuda:0) = onnx::MaxPool[ceil_mode=0, kernel_shape=[2, 2], pads=[1, 1, 1, 1], strides=[1, 1], onnx_name="/all_layers/all_layers.8/MaxPool"](%/all_layers/all_layers.7/Relu_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.pooling.MaxPool2d::all_layers.8 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:791:0
#   %/all_layers/all_layers.9/ConvTranspose_output_0 : Float(1, 38, 28, 28, strides=[29792, 784, 28, 1], requires_grad=0, device=cuda:0) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/all_layers/all_layers.9/ConvTranspose"](%/all_layers/all_layers.8/MaxPool_output_0, %all_layers.9.weight, %all_layers.9.bias), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.conv.ConvTranspose2d::all_layers.9 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:952:0
#   %/all_layers/all_layers.10/Relu_output_0 : Float(1, 38, 28, 28, strides=[29792, 784, 28, 1], requires_grad=0, device=cuda:0) = onnx::Relu[onnx_name="/all_layers/all_layers.10/Relu"](%/all_layers/all_layers.9/ConvTranspose_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.activation.ReLU::all_layers.10 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:1471:0
#   %/all_layers/all_layers.11/ConvTranspose_output_0 : Float(1, 76, 29, 29, strides=[63916, 841, 29, 1], requires_grad=0, device=cuda:0) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/all_layers/all_layers.11/ConvTranspose"](%/all_layers/all_layers.10/Relu_output_0, %all_layers.11.weight, %all_layers.11.bias), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.conv.ConvTranspose2d::all_layers.11 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:952:0
#   %/all_layers/all_layers.12/Relu_output_0 : Float(1, 76, 29, 29, strides=[63916, 841, 29, 1], requires_grad=0, device=cuda:0) = onnx::Relu[onnx_name="/all_layers/all_layers.12/Relu"](%/all_layers/all_layers.11/ConvTranspose_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.activation.ReLU::all_layers.12 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:1471:0
#   %/all_layers/all_layers.13/ConvTranspose_output_0 : Float(1, 1, 30, 30, strides=[900, 900, 30, 1], requires_grad=0, device=cuda:0) = onnx::ConvTranspose[dilations=[1, 1], group=1, kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[1, 1], onnx_name="/all_layers/all_layers.13/ConvTranspose"](%/all_layers/all_layers.12/Relu_output_0, %all_layers.13.weight, %all_layers.13.bias), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.conv.ConvTranspose2d::all_layers.13 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:952:0
#   %output : Float(1, 1, 30, 30, strides=[900, 900, 30, 1], requires_grad=0, device=cuda:0) = onnx::Sigmoid[onnx_name="/all_layers/all_layers.14/Sigmoid"](%/all_layers/all_layers.13/ConvTranspose_output_0), scope: models.autoencoders.ConvAutoencoderLuma.ConvAutoencoderLuma::/torch.nn.modules.container.Sequential::all_layers/torch.nn.modules.activation.Sigmoid::all_layers.14 # /home/amedvedev/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/activation.py:292:0
#   return (%output)

# %%
env.test_on_dataset(include_train=False, include_test=True, cmap="jet")
# Out:
# Testing data: /home/amedvedev/fprojects/python/denoising/data/datasets/gcg18/val
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 env.test_on_dataset(include_train=False, include_test=True, cmap="jet")
#
# File ~/fprojects/python/denoising/applications/denoiser_environment.py:271, in DenoiserEnvironment.test_on_dataset(self, include_train, include_test, csv, txt, png, cmap)
#     268     basic_test(self.path_train, self.width, self.height, report_train_path, self.model, self.device, csv, txt, png, cmap=cmap)
#     270 if include_test:
# --> 271     basic_test(self.path_test, self.width, self.height, report_test_val_path, self.model, self.device, csv, txt,
#     272            png, cmap=cmap)
#     274 print("Testing ended.")
#
# File ~/fprojects/python/denoising/testing/basic_test.py:41, in basic_test(data_path, width, height, save_path, model, device, csv, txt, png, cmap)
#      38 noised_arr = read_matrix(noised_fp)
#      39 noised_arr_scaled = rescale_array(noised_arr)
# ---> 41 res_neuro_arr = rescale_array(model(
#      42     torch.tensor(noised_arr_scaled, dtype=torch.float, device=device).resize(1, 1, width, height)
#      43 ).resize(width, height).detach().cpu().numpy(), to=(np.min(noised_arr), np.max(noised_arr)))
#      45 if csv:
#      46     csv_dir = os.path.join(save_path, "csv", "test", f"{new_name}.csv")
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/fprojects/python/denoising/models/experimental/UvychToKre3.py:20, in UvychToKre3.forward(self, x)
#      19 def forward(self, x):
# ---> 20     x = self.block1(x)
#      21     x = self.block2(x)
#      22     return x
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/fprojects/python/denoising/models/experimental/UvychToKre2.py:32, in UvychToKre2.forward(self, x)
#      29 x = x.view(x.size()[0], 900)
#      31 x = self.ln1(x)
# ---> 32 x = self.bn1(x)
#      33 x1 = self.selu(x)
#      35 x = self.ln2(x1)
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py:171, in _BatchNorm.forward(self, input)
#     164     bn_training = (self.running_mean is None) and (self.running_var is None)
#     166 r"""
#     167 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     168 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     169 used for normalization (i.e. in eval mode when buffers are not None).
#     170 """
# --> 171 return F.batch_norm(
#     172     input,
#     173     # If buffers are not to be tracked, ensure that they won't be updated
#     174     self.running_mean
#     175     if not self.training or self.track_running_stats
#     176     else None,
#     177     self.running_var if not self.training or self.track_running_stats else None,
#     178     self.weight,
#     179     self.bias,
#     180     bn_training,
#     181     exponential_average_factor,
#     182     self.eps,
#     183 )
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:2476, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2463     return handle_torch_function(
#    2464         batch_norm,
#    2465         (input, running_mean, running_var, weight, bias),
#    (...)
#    2473         eps=eps,
#    2474     )
#    2475 if training:
# -> 2476     _verify_batch_size(input.size())
#    2478 return torch.batch_norm(
#    2479     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2480 )
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/functional.py:2444, in _verify_batch_size(size)
#    2442     size_prods *= size[i + 2]
#    2443 if size_prods == 1:
# -> 2444     raise ValueError(f"Expected more than 1 value per channel when training, got input size {size}")
#
# ValueError: Expected more than 1 value per channel when training, got input size torch.Size([1, 1024])

# %%
env.show_single(concrete=None, op_count=1, figsize=(15, 10), cmap="jet")
# Out:
# Show example №41

# %%
import gc
gc.collect()
# Out:
# 81250

# %%
import torch
env.model.cpu()
del env.model

torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 import torch
# ----> 2 env.model.cpu()
#       3 del env.model
#       5 torch.cuda.empty_cache()
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:967, in Module.cpu(self)
#     958 def cpu(self: T) -> T:
#     959     r"""Moves all model parameters and buffers to the CPU.
#     960
#     961     .. note::
#    (...)
#     965         Module: self
#     966     """
# --> 967     return self._apply(lambda t: t.cpu())
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:833, in Module._apply(self, fn, recurse)
#     829 # Tensors stored in modules are graph leaves, and we don't want to
#     830 # track autograd history of `param_applied`, so we have to use
#     831 # `with torch.no_grad():`
#     832 with torch.no_grad():
# --> 833     param_applied = fn(param)
#     834 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     835 if should_use_set_data:
#
# File ~/fprojects/python/denoising/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:967, in Module.cpu.<locals>.<lambda>(t)
#     958 def cpu(self: T) -> T:
#     959     r"""Moves all model parameters and buffers to the CPU.
#     960
#     961     .. note::
#    (...)
#     965         Module: self
#     966     """
# --> 967     return self._apply(lambda t: t.cpu())
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
from datageneration.generators import GenPolyDataset
from datageneration import paramsgens

generate_settings = [("train", 800), ("val", 100)]

for (data_category, count) in generate_settings:
    env.generate_data(NAME_DATASET, data_category, n=count, width=width, height=height,
                      cell_size=paramsgens.GenCellSizeInSet([1, 2]),
                      pct_noise=paramsgens.GenPctUniformNoiseRange(a=0.01, b=0.05),
                      k0=paramsgens.GenK0InRange(min_val=3, max_val=100),
                      csv=True, txt=True, png=True,
                      generator_class=GenPolyDataset,
                      )

# pct_noise=0.1, k0=55.0,
# Out:
# Generating dataset gcg18/train...
# Progress: |██████████████████████████████| 100.0% Complete |
#
# Generating dataset gcg18/val...
# Progress: |██████████████████████████████| 100.0% Complete |

# %%
env.model.parameters()
# Out:
# <generator object Module.parameters at 0x7fa73fa39700>

# %%
sum(p.numel() for p in env.model.parameters() if p.requires_grad)
# Out:
# 90788632
