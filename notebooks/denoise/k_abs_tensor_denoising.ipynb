# %% [markdown]
# ## Библиотеки, параметры, константы задачи

# %%
from applications.poly_features_environment import PolyFeaturesEnv
import torch
import models
import numpy as np
from common.fstream import read_tensor, read_matrix, rescale_array, read_mc_tensor

PATH_BASE = "/home/amedvedev/projects/python/DenoisingCNN"
NAME_DATASET = "gcg19"
env = PolyFeaturesEnv(name_model="k_tensor_denoiser_3", name_dataset=NAME_DATASET, path_base=PATH_BASE,
                      device_name="cuda")

# %% [markdown]
# ## Загрузка данных

# %%
env.clear_features_and_targets()
env \
    .set_batch_size(
        train_batch_size=16, val_batch_size=4
    ) \
    .load_feature(
        shape=(64, 80, 80), feature_name="K_abs_noised.tensor", mapper=lambda path: read_mc_tensor(path, (((0., 1.)), None)), transform=None
    ) \
    .set_target(
        shape=(1, 80, 80), target_name="K_abs.xls", mapper=lambda path: read_matrix(path), transform=None
    ) \

print(env.train_count, env.val_count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 env.clear_features_and_targets()
# ----> 2 env \
#       3     .set_batch_size(
#       4         train_batch_size=16, val_batch_size=4
#       5     ) \
#       6     .load_feature(
#       7         shape=(64, 80, 80), feature_name="K_abs_noised.tensor", mapper=lambda path: read_mc_tensor(path, (((0., 1.)), None)), transform=None
#       8     ) \
#       9     .set_target(
#      10         shape=(1, 80, 80), target_name="K_abs.xls", mapper=lambda path: read_matrix(path), transform=None
#      11     ) \
#      13 print(env.train_count, env.val_count)
#
# File ~/projects/python/DenoisingCNN/applications/poly_features_environment.py:72, in PolyFeaturesEnv.load_feature(self, shape, feature_name, mapper, transform, lazy_load, pct_load)
#      69 def load_feature(self, shape, feature_name, mapper, transform=None, lazy_load=False, pct_load=None):
#      71     self.train_features_loaders.append(
# ---> 72         FeatureLoader2d(
#      73             self.path_train, feature_name, self.device, self.train_batch_size, shape, mapper, transform, lazy_load, pct_load
#      74         )
#      75     )
#      77     if self.train_count is None:
#      78         self.train_count = len(self.train_features_loaders[-1])
#
# File ~/projects/python/DenoisingCNN/dataloaders/featureloader2d_v2.py:53, in FeatureLoader2d.__init__(self, data_dir, feature, device, batch_size, shape, read_tensor, transform, lazy_load, pct_load)
#      51 self.items = []
#      52 for idx in range(len(self.data)):
# ---> 53     self.items.append(self.load_item(idx))
#      54     printProgressBar(idx, len(self.data), prefix='Data loading progress:', suffix='Complete',
#      55                      length=50)
#
# File ~/projects/python/DenoisingCNN/dataloaders/featureloader2d_v2.py:68, in FeatureLoader2d.load_item(self, idx)
#      67 def load_item(self, idx):
# ---> 68     content = list(map(self.read_tensor, self.data[idx]))
#      70     batch = torch.tensor(np.array(list(map(lambda el: np.array(el),
#      71                                            content))), dtype=torch.float, device=self.device)
#      73     if self.transform:
#
# Cell In[2], line 7, in <lambda>(path)
#       1 env.clear_features_and_targets()
#       2 env \
#       3     .set_batch_size(
#       4         train_batch_size=16, val_batch_size=4
#       5     ) \
#       6     .load_feature(
# ----> 7         shape=(64, 80, 80), feature_name="K_abs_noised.tensor", mapper=lambda path: read_mc_tensor(path, (((0., 1.)), None)), transform=None
#       8     ) \
#       9     .set_target(
#      10         shape=(1, 80, 80), target_name="K_abs.xls", mapper=lambda path: read_matrix(path), transform=None
#      11     ) \
#      13 print(env.train_count, env.val_count)
#
# File ~/projects/python/DenoisingCNN/common/fstream.py:26, in read_mc_tensor(path, rescale_each)
#      24 if rescale_each:
#      25     for i in range(len(data)):
# ---> 26         data[i] = rescale_array(np.array(data[i]), rescale_each[1], rescale_each[0])
#      27 return np.array(data)
#
# File ~/projects/python/DenoisingCNN/common/matrix.py:10, in rescale_array(a, to, fr_rng)
#       8 if fr_rng is None:
#       9     fr_rng = (a.min(), a.max())
# ---> 10 return np.interp(a, fr_rng, to)
#
# File <__array_function__ internals>:200, in interp(*args, **kwargs)
#
# File ~/projects/python/DenoisingCNN/venv/lib/python3.10/site-packages/numpy/lib/function_base.py:1595, in interp(x, xp, fp, left, right, period)
#    1592     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1593     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1595 return interp_func(x, xp, fp, left, right)
#
# ValueError: object of too small depth for desired array

# %% [markdown]
# ## Модели

# %% [markdown]
# ### Новая локальная модель

# %%
env.model = models.autoencoders.ConvAutoencoderLumaRelu8(in_channels=64, out_channels=1).to(env.device)

# %%
env.model
# Out:
# ConvAutoencoderLumaRelu8(
#   (encoder): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): AvgPool2d(kernel_size=2, stride=1, padding=0)
#     (3): Conv2d(64, 128, kernel_size=(2, 2), stride=(1, 1))
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): AvgPool2d(kernel_size=2, stride=1, padding=0)
#     (6): Conv2d(128, 256, kernel_size=(2, 2), stride=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): AvgPool2d(kernel_size=2, stride=1, padding=1)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): ConvTranspose2d(64, 1, kernel_size=(2, 2), stride=(1, 1))
#   )
# )

# %% [markdown]
# ### Импорт претренерованной модели

# %%
env.load_model(model_type="pt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/projects/python/DenoisingCNN/applications/abstract_environment.py:25, in AbstractEnvironment.load_model(self, model_type)
#      24 try:
# ---> 25     self.model = torch.load(self.path_save_model(model_type)).to(self.device)
#      27 except Exception as e:
#
# File ~/projects/python/DenoisingCNN/venv/lib/python3.10/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#
# File ~/projects/python/DenoisingCNN/venv/lib/python3.10/site-packages/torch/serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     444 if _is_path(name_or_buffer):
# --> 445     return _open_file(name_or_buffer, mode)
#     446 else:
#
# File ~/projects/python/DenoisingCNN/venv/lib/python3.10/site-packages/torch/serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/amedvedev/projects/python/DenoisingCNN/assets/pt/k_tensor_denoiser_1.pt'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 env.load_model(model_type="pt")
#
# File ~/projects/python/DenoisingCNN/applications/abstract_environment.py:28, in AbstractEnvironment.load_model(self, model_type)
#      25     self.model = torch.load(self.path_save_model(model_type)).to(self.device)
#      27 except Exception as e:
# ---> 28     self.init_model()
#      29     print("Error when loading pretrained model. Use custom.", e)
#
# File ~/projects/python/DenoisingCNN/applications/abstract_environment.py:35, in AbstractEnvironment.init_model(self, model_class)
#      33     self.model = model_class().to(self.device)
#      34 else:
# ---> 35     self.model = models.get_basic_model().to(self.device)
#      36 print("New model created.")
#
# File ~/projects/python/DenoisingCNN/models/__init__.py:20, in get_basic_model()
#      19 def get_basic_model():
# ---> 20     return ConvAutoencoderLuma()
#
# TypeError: ConvAutoencoderLuma.__init__() missing 2 required positional arguments: 'in_channels' and 'out_channels'

# %% [markdown]
# ## Визуализация батча валидационного датасета

# %%
env.plot_batch(concrete=5, figsize=(10, 10), format="%.1f", wspace=0.0, hspace=0.2)

# %% [markdown]
# ## Численные значения отклонений

# %%
def test():
    losses = []
    errors = []
    init_errors = []
    losses_dataset = []
    with torch.no_grad():
    
        for row in zip(*env.val_features_loaders + [env.val_target_loader]):
            data_features = list(row)
            data_target = data_features.pop()
            outputs = env.model(*data_features) #* 65.
            
            for ex_id in range(env.val_batch_size):
                
                for j in range(64):
                    losses_dataset_step = torch.mean(torch.abs(data_features[0][ex_id][j] - data_target[ex_id])).detach().tolist()
                    losses_dataset.append(losses_dataset_step)
                    
                    init_error = torch.mean(torch.abs(data_features[0][ex_id][j] - data_target[ex_id]) / data_target[ex_id])
                    init_errors.append(init_error.detach().tolist())
                
                loss = torch.mean(torch.abs(outputs[ex_id] - data_target[ex_id]))
                losses.append(loss.detach().tolist())
                # print(data_target[ex_id].size())
                
                
                error = torch.mean(torch.abs(outputs[ex_id] - data_target[ex_id]) / data_target[ex_id])
                errors.append(error.detach().tolist())
                #print(outputs, data_target)
                
    print("Начальное среднее отклонение по значениям:", sum(losses_dataset) / len(losses_dataset))
    print("Текущее среднее отклонение по значениям:", sum(losses) / len(losses))
    
    print()
    print("Начальное максимальное отклонение по значениям:", max(losses_dataset))
    print("Текущее максимальное отклонение по значениям в векторе:", max(losses))
    
    print()
    print("Начальная средняя относительная ошибка:", sum(init_errors) / len(init_errors))
    print("Текущая средняя относительная ошибка:", sum(errors) / len(errors))
    print()
    print("Начальная максимальная относительная ошибка:", max(init_errors))
    print("Текущая максимальная относительная ошибка:", max(errors))
test()
# Out:
# Начальное среднее отклонение по значениям: 0.6074315004598247
# Текущее среднее отклонение по значениям: 0.29994630126748234
#
# Начальное максимальное отклонение по значениям: 1.2703033685684204
# Текущее максимальное отклонение по значениям в векторе: 1.5500177145004272
#
# Начальная средняя относительная ошибка: 0.024994828536364366
# Текущая средняя относительная ошибка: 0.01677366027433891
#
# Начальная максимальная относительная ошибка: 0.02572666108608246
# Текущая максимальная относительная ошибка: 0.08197460323572159

# %% [markdown]
# ## Training

# %%
from common.losses import MseCoeffLoss, L1CoeffLoss

# %%
env.train(10, step_saving=False, step_plotting=False,
          optimizer=torch.optim.Adam(env.model.parameters(), lr=0.01), scheduler=None, 
          criterion=torch.nn.BCELoss(reduction="none", reduce="none"))
# Out:
# /home/amedvedev/projects/python/DenoisingCNN/venv/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 1 	Training Loss: 3.032132 	Validating Loss: 0.695596 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 2 	Training Loss: 0.691567 	Validating Loss: 0.697662 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 3 	Training Loss: 0.691231 	Validating Loss: 0.697039 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 4 	Training Loss: 0.691201 	Validating Loss: 0.695897 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 5 	Training Loss: 0.691134 	Validating Loss: 0.695971 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 6 	Training Loss: 0.690941 	Validating Loss: 0.697842 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 7 	Training Loss: 0.691159 	Validating Loss: 0.693802 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 8 	Training Loss: 0.691508 	Validating Loss: 0.693448 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 9 	Training Loss: 0.691607 	Validating Loss: 0.693642 	Time: 0.42 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 10 	Training Loss: 0.691351 	Validating Loss: 0.693976 	Time: 0.42 m
#
# ====================================================================================================

# %%
env.set_name_model("k_tensor_denoiser_1")

# %%
opt = torch.optim.Adam(env.model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(opt, patience=3, verbose=True)

# %%
env.train(30 , step_saving=False, step_plotting=False,
          optimizer=opt, scheduler=None, 
          criterion=torch.nn.MSELoss(reduce="none", reduction="none"), callbacks=[lambda: scheduler.step(env.test_losses[-1])])
# Out:
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 1 	Training Loss: 1.781186 	Validating Loss: 1.422220 	Time: 0.60 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 2 	Training Loss: 1.788211 	Validating Loss: 2.131769 	Time: 0.56 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 3 	Training Loss: 2.341177 	Validating Loss: 1.300081 	Time: 0.52 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 4 	Training Loss: 1.575476 	Validating Loss: 1.633869 	Time: 0.52 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 5 	Training Loss: 2.278340 	Validating Loss: 2.976475 	Time: 0.52 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 6 	Training Loss: 265670568673010.843750 	Validating Loss: 7847875559424.000000 	Time: 0.50 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 7 	Training Loss: 5525141310892.218750 	Validating Loss: 1054694026240.000000 	Time: 0.50 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 8 	Training Loss: 280129662082.327209 	Validating Loss: 52872860480.000000 	Time: 0.56 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 9 	Training Loss: 44376458686.836357 	Validating Loss: 28377208992.000000 	Time: 0.55 m
#
# ====================================================================================================
# Training progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Validating progress: |██████████████████████████████████████████████████| 100.0% Complete |
#
# Epoch: 10 	Training Loss: 21474673068.218178 	Validating Loss: 14324785496.000000 	Time: 0.52 m
#
# ====================================================================================================
# Training progress: |█████████████████████████████████-----------------| 67.3% Complete |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 env.train(30 , step_saving=False, step_plotting=False,
#       2           optimizer=opt, scheduler=None,
#       3           criterion=torch.nn.MSELoss(reduce="none", reduction="none"), callbacks=[lambda: scheduler.step(env.test_losses[-1])])
#
# File ~/projects/python/DenoisingCNN/applications/poly_features_environment.py:223, in PolyFeaturesEnv.train(self, epochs, criterion, optimizer, scheduler, step_saving, step_plotting, callbacks)
#     220 loss.backward()
#     221 optimizer.step()
# --> 223 loss_deltha = loss.item()
#     224 train_loss += loss_deltha / self.train_count
#     225 itr += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Сохранение модели

# %%
env.save(onnx=False, pth=False)

# %% [markdown]
# ## Loss visualisation

# %%
env.show_metrics(n_last=10, train=True, val=True)

# %% [markdown]
# ## Clear memory

# %%
import gc
gc.collect()
# Out:
# 42128

# %%
env.model.cpu()
del env.model

torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 env.model.cpu()
#       2 del env.model
#       4 torch.cuda.empty_cache()
#
# AttributeError: 'NoneType' object has no attribute 'cpu'
